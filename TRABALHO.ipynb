# %%
Nome = list()
Idade = list()
Telefone = list()
Dados = [Nome, Idade, Telefone]
menu = "S"

while menu == "S":
    menu=int(input("BEM VINDO AO SISTEMA ESCOLAR \nDIGITE   1 - CADASTRAR   2 - EXCLUIR   3 - ALTERAR   4 - LISTAR   0 - SAIR "))
    if menu == 1:
        nome_aluno= str(input("Digite o nome do Aluno: ")).upper()
        if nome_aluno in Nome:
            print("Me desculpe mas, o Aluno que solicitou já está matriculado.")
            print("Tente outro Aluno Por Favor!")
            menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]\n")).upper()

        else:
            Nome.append(nome_aluno)
            idade_aluno = int(input("Digite sua Idade: "))
            Idade.append(idade_aluno) 
            tell_aluno = int(input("Digite seu Telefone: "))
            Telefone.append(tell_aluno)
            Dados.append(Nome)
            Dados.append(Idade)
            Dados.append(Telefone)
            print("O Cadastro da Aluno foi realizado com Sucesso!\n")
            menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]\n")).upper()
    elif menu == 2:
        nome_aluno = str(input("Digite o Aluno no qual deseja ser Removido do Cadastro: ")).upper() 
        if nome_aluno in Nome:
            Nome.remove(nome_aluno)
        idade_aluno = int(input("Precisa-se da idade do aluno para remover: "))
        if idade_aluno in Idade:
            Idade.remove(idade_aluno)
        telefone_aluno = int(input("Precisa-se do seu Telefone se Tiver algum disponivel: "))
        if tell_aluno in Telefone:
            Telefone.remove(tell_aluno)
            print("Os Dados pessoais do Aluno foram apagados com Sucesso!\n")
            menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]")).upper()

        else:
            print("\nEste Aluno não está cadastrado no Banco de Dados.\n")
            menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]")).upper()
    elif menu == 3:
        nome_aluno = str(input("Digite o Aluno para ser Alterado: ")).upper()
        Nome.index(nome_aluno)
        print(nome_aluno)
        if nome_aluno in Nome:
            Nome.remove(nome_aluno)
            nome_aluno=str(input("Qual o Nome do Aluno vai ser agora?: "))
            Nome.append(nome_aluno)
            menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]")).upper()
        else:
            print("\nEste Aluno não está cadastrado no Bancod e Dados.")
            menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]")).upper()
    elif menu == 4:
        print("\nNomes: {} \nIdade: {} \ntelefone: {}\n".format(Nome, Idade, Telefone))
        menu=str(input("Deseja Voltar ao menu? \nDigite [S/N]")).upper()    
    elif menu == 0:
        print(" SAINDO ...")
