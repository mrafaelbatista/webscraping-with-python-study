# %% [markdown]
# # Introdução

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bsObj = BeautifulSoup(html)

# %%
for link in bsObj.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(1990_film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# #cite_note-32
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-39
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# #cite_note-40
# #cite_note-41
# #cite_note-42
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-43
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-44
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-45
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-46
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-47
# /wiki/Tracy_Pollan
# #cite_note-48
# #cite_note-49
# #cite_note-50
# /wiki/The_Times
# #cite_note-51
# #cite_note-52
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-53
# #cite_note-54
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-55
# #cite_note-56
# #cite_note-57
# #cite_note-58
# /wiki/Apollo_13_(film)
# #cite_note-59
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-60
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-61
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-62
# /wiki/Denver_Film_Festival
# #cite_note-63
# /wiki/Phoenix_Film_Festival
# #cite_note-64
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-65
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-66
# /wiki/Seattle_International_Film_Festival
# #cite_note-67
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.sixdegrees.org/
# #cite_ref-44
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-45
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-46
# http://baconbros.com/
# #cite_ref-47
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-48
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-49
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-50
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-51
# #cite_ref-52
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_53-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-54
# #cite_ref-55
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-56
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-57
# http://www.drawtheline.org/sign-now/
# #cite_ref-58
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-59
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-60
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-61
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-62
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-63
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-64
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-65
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-66
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-67
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# https://en.wikipedia.org/w/index.php?title=Template:Golden_Globe_Best_Actor_TV_Miniseries_Film&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# /wiki/BIBSYS_(identifier)
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# /wiki/BNE_(identifier)
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# /wiki/BNF_(identifier)
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# /wiki/GND_(identifier)
# https://d-nb.info/gnd/124109659
# /wiki/ISNI_(identifier)
# https://isni.org/isni/0000000121291300
# /wiki/LCCN_(identifier)
# https://id.loc.gov/authorities/names/n88034930
# /wiki/LNB_(identifier)
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# /wiki/MBA_(identifier)
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/NKC_(identifier)
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# /wiki/NLA_(identifier)
# https://nla.gov.au/anbd.aut-an36021861
# /wiki/NLI_(identifier)
# http://uli.nli.org.il/F/?func=direct&doc_number=002168993&local_base=nlx10
# /wiki/NLP_(identifier)
# https://tools.wmflabs.org/wikidata-externalid-url?p=1695&id=A1257000X
# /wiki/NTA_(identifier)
# http://data.bibliotheken.nl/id/thes/p147880998
# /wiki/PLWABN_(identifier)
# http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&NU=1&IM=4&WI=9810630778405606
# /wiki/RERO_(identifier)
# http://data.rero.ch/02-A016294166
# /wiki/SNAC-ID_(identifier)
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/084292652
# https://www.idref.fr/067287832
# /wiki/Trove_(identifier)
# https://trove.nla.gov.au/people/1189569
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/39570812
# /wiki/WorldCat_Identities_(identifier)
# https://www.worldcat.org/identities/lccn-n88034930
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1010916802
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Wikipedia_articles_with_BIBSYS_identifiers
# /wiki/Category:Wikipedia_articles_with_BNE_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_LNB_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_NLA_identifiers
# /wiki/Category:Wikipedia_articles_with_NLI_identifiers
# /wiki/Category:Wikipedia_articles_with_NLP_identifiers
# /wiki/Category:Wikipedia_articles_with_NTA_identifiers
# /wiki/Category:Wikipedia_articles_with_PLWABN_identifiers
# /wiki/Category:Wikipedia_articles_with_RERO_identifiers
# /wiki/Category:Wikipedia_articles_with_SNAC-ID_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_Trove_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_WORLDCATID_identifiers
# /wiki/Category:Wikipedia_articles_with_multiple_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1010916802
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1010916802&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
import re

for link in bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$")):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/EE_(telecommunications_company)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Lortel_Archives
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/BIBSYS_(identifier)
# /wiki/BNE_(identifier)
# /wiki/BNF_(identifier)
# /wiki/GND_(identifier)
# /wiki/ISNI_(identifier)
# /wiki/LCCN_(identifier)
# /wiki/LNB_(identifier)
# /wiki/MBA_(identifier)
# /wiki/NKC_(identifier)
# /wiki/NLA_(identifier)
# /wiki/NLI_(identifier)
# /wiki/NLP_(identifier)
# /wiki/NTA_(identifier)
# /wiki/PLWABN_(identifier)
# /wiki/RERO_(identifier)
# /wiki/SNAC-ID_(identifier)
# /wiki/SUDOC_(identifier)
# /wiki/Trove_(identifier)
# /wiki/VIAF_(identifier)
# /wiki/WorldCat_Identities_(identifier)

# %% [markdown]
# # Percorrendo um único domínio

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime, random, re

# %%
random.seed(datetime.datetime.now())

# %%
def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl)
    bsObj = BeautifulSoup(html)
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))

# %%
links = getLinks("/wiki/Kevin_Bacon")

# %%
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Kyra_Sedgwick
# /wiki/Olivia_Colman
# /wiki/The_London_Gazette
# /wiki/RDFa
# /wiki/Resource_Description_Framework
# /wiki/RDF_Schema
# /wiki/Extensible_User_Interface_Protocol
# /wiki/HTML
# /wiki/IEC_61334
# /wiki/RS-232
# /wiki/Breakout_box
# /wiki/RS-232
# /wiki/RS-423
# /wiki/Industry_Standard_Architecture
# /wiki/X86
# /wiki/P5_(microarchitecture)
# /wiki/Socket_7
# /wiki/Socket_495
# /wiki/Pentium_II
# /wiki/Pentium_III
# /wiki/List_of_Intel_Pentium_II_microprocessors
# /wiki/Diamondville_(microprocessor)
# /wiki/Streaming_SIMD_Extensions
# /wiki/Microarchitecture
# /wiki/Memory_address_register
# /wiki/Central_processing_unit
# /wiki/Phone_connector_(audio)
# /wiki/IPod_Shuffle
# /wiki/Delano_Lewis
# /wiki/Schoolwork_(Apple)
# /wiki/OS_X_Mavericks
# /wiki/DigitalColor_Meter
# /wiki/Apple_News
# /wiki/Apple_Worldwide_Developers_Conference
# /wiki/Eddy_Cue
# /wiki/Craig_Federighi
# /wiki/CarPlay
# /wiki/Apple_Inc.
# /wiki/Smart_Keyboard
# /wiki/IPad_Pro
# /wiki/Apple_Watch_Series_2
# /wiki/Apple_Watch
# /wiki/Apple_S2
# /wiki/IPad_(2019)
# /wiki/HomePod_Mini
# /wiki/Apple_M1
# /wiki/Apple_Desktop_Bus
# /wiki/Application-specific_integrated_circuit
# /wiki/Cognitive_computing
# /wiki/Affective_computing
# /wiki/Contempt
# /wiki/Shame
# /wiki/PMID_(identifier)
# /wiki/List_of_academic_databases_and_search_engines
# /wiki/The_Zoological_Record
# /wiki/Arachnida
# /wiki/Coxal_gland
# /wiki/Spider
# /wiki/Spider_bite
# /wiki/Anaphylaxis
# /wiki/PMID_(identifier)
# /wiki/Health_2.0
# /wiki/Doi_(identifier)
# /wiki/Handle_System
# /wiki/Linked_Data
# /wiki/Open_energy_system_databases
# /wiki/CC_BY
# /wiki/Open_innovation
# /wiki/OCLC_(identifier)
# /wiki/National_Education_Association
# /wiki/Wisconsin
# /wiki/OCLC_(identifier)
# /wiki/Integrated_library_system
# /wiki/Cybernetics
# /wiki/Communism
# /wiki/Soviet_Union
# /wiki/Korenizatsiya
# /wiki/ISBN_(identifier)
# /wiki/ISO_31-5
# /wiki/Accuracy_and_precision
# /wiki/XML_Metadata_Interchange
# /wiki/Meta-Object_Facility
# /wiki/PHIGS
# /wiki/Non-uniform_rational_B-spline
# /wiki/Constant_function
# /wiki/Function_of_several_real_variables
# /wiki/Function_space
# /wiki/Ordered_pair
# /wiki/Logical_consequence
# /wiki/Venn_diagram
# /wiki/Recursion
# /wiki/Mathematical_logic
# /wiki/Rendering_(computer_graphics)
# /wiki/Computer_vision
# /wiki/Image_sensor
# /wiki/Digital_camera
# /wiki/Diving_support_vessel
# /wiki/Fran%C3%A7ois_de_Roubaix
# /wiki/Lipid
# /wiki/Terpene
# /wiki/Geosmin
# /wiki/Magnesium
# /wiki/Nitrogen
# /wiki/Ovum
# /wiki/Reproductive_system
# /wiki/Genitalia
# /wiki/Cervix
# /wiki/Clitoris#Glans_and_body
# /wiki/Jacques_Dal%C3%A9champs
# /wiki/SELIBR_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISO_860
# /wiki/ISO_9897
# /wiki/ISO_19092-1
# /wiki/ISO_8178
# /wiki/ISO_10160
# /wiki/ISO/TR_11941
# /wiki/Yale_romanization_of_Korean
# /wiki/Samuel_Martin_(linguist)
# /wiki/Pittsburg,_Kansas
# /wiki/Dunkirk,_Kansas
# /wiki/Washington_Township,_Crawford_County,_Kansas
# /wiki/Opolis,_Kansas
# /wiki/Pittsburg,_Kansas
# /wiki/St._Mary%27s-Colgan_High_School
# /wiki/Roman_Catholic_Diocese_of_Wichita
# /wiki/Emil_Kapaun
# /wiki/Great_martyr
# /wiki/Agatha_of_Sicily
# /wiki/Child_Martyrs_of_Tlaxcala
# /wiki/Cyprian
# /wiki/Use_of_Sarum
# /wiki/Pre-Tridentine_Mass
# /wiki/Sabbath_in_Christianity#Roman_Catholicism
# /wiki/Week
# /wiki/Calendar
# /wiki/Dionysius_Exiguus
# /wiki/Laurentius_Suslyga
# /wiki/History
# /wiki/Incremental_dating
# /wiki/Global_Standard_Stratigraphic_Age
# /wiki/Global_Boundary_Stratotype_Section_and_Point
# /wiki/Geologic_Calendar
# /wiki/Tzolk%27in
# /wiki/Maya_civilization
# /wiki/Maya_society
# /wiki/Spanish_conquest_of_Chiapas
# /wiki/Bernal_D%C3%ADaz_del_Castillo
# /wiki/Juan_Pardo_(explorer)
# /wiki/Francisco_Pizarro
# /wiki/League_(unit)
# /wiki/Spanish_customary_units
# /wiki/Hectare
# /wiki/Land_management
# /wiki/ASIN_(identifier)
# /wiki/Amazon_Game_Studios
# /wiki/Shelfari
# /wiki/CDNow
# /wiki/Alexa_Internet
# /wiki/Digital_Photography_Review
# /wiki/Annapurna_Labs
# /wiki/List_of_mergers_and_acquisitions_by_Amazon
# /wiki/Askville
# /wiki/Zappos
# /wiki/The_Mint_Las_Vegas
# /wiki/Bourbon_Street_Hotel_and_Casino
# /wiki/Westward_Ho_Hotel_and_Casino
# /wiki/Santa_Fe_Station
# /wiki/Sahara_Las_Vegas
# /wiki/The_Strat_(Las_Vegas)
# /wiki/Sam_Boyd_Stadium
# /wiki/The_Forum_Shops_at_Caesars
# /wiki/Mandalay_Bay_Tram
# /wiki/Harrah%27s_Las_Vegas
# /wiki/Royal_Nevada
# /wiki/The_Drew_Las_Vegas
# /wiki/Railroad_Pass_Casino
# /wiki/Nevada_State_Route_582
# /wiki/Nevada_State_Route_562
# /wiki/List_of_state_routes_in_Nevada
# /wiki/Reno,_Nevada
# /wiki/Southern_California
# /wiki/Central_California
# /wiki/California_State_Route_99
# /wiki/Marysville,_California
# /wiki/Marysville_station_(California)
# /wiki/San_Francisco_Examiner
# /wiki/William_Randolph_Hearst
# /wiki/History_of_American_newspapers
# /wiki/ISBN_(identifier)
# /wiki/XML_Metadata_Interchange
# /wiki/Common_Warehouse_Metamodel
# /wiki/Metadata
# /wiki/Systems_engineering
# /wiki/Mathematical_optimization
# /wiki/Doi_(identifier)
# /wiki/ISO_13490
# /wiki/ISO_15022
# /wiki/Ontology_(information_science)
# /wiki/Etymology
# /wiki/Germanic_languages
# /wiki/Palatine_German_language
# /wiki/Middle_Low_German
# /wiki/Glottolog
# /wiki/Pauwasi_languages
# /wiki/Binanderean%E2%80%93Goilalan_languages
# /wiki/Xincan_languages
# /wiki/Abinomn_language
# /wiki/Esselen_language
# /wiki/Nasal_consonant
# /wiki/Airstream_mechanism
# /wiki/Uvular_consonant
# /wiki/Nasal_consonant
# /wiki/Postalveolar_consonant
# /wiki/TIPA_(software)
# /wiki/Retroflex_ejective_fricative
# /wiki/Palato-alveolar_ejective_fricative
# /wiki/Voiceless_alveolar_lateral_affricate
# /wiki/Tap_and_flap_consonants
# /wiki/Lateral_consonant
# /wiki/Voiced_velar_affricate
# /wiki/Voiceless_pharyngeal_fricative
# /wiki/Voiceless_bidental_fricative
# /wiki/World_Orthography
# /wiki/Voiceless_retroflex_fricative
# /wiki/Voiceless_bilabial_affricate
# /wiki/Labiodental_consonant
# /wiki/Voiced_labiodental_affricate
# /wiki/Mid_vowel
# /wiki/Mid_front_unrounded_vowel
# /wiki/Postalveolar_consonant
# /wiki/Voiceless_bilabial_implosive
# /wiki/International_Phonetic_Alphabet
# /wiki/Phoneme
# /wiki/Minimal_pair
# /wiki/Italian_language
# /wiki/Italian_Armed_Forces
# /wiki/Joint_European_Union_Intelligence_School
# /wiki/European_Border_and_Coast_Guard_Agency
# /wiki/2015%E2%80%9316_New_Year%27s_Eve_sexual_assaults_in_Germany
# /wiki/Islamophobia_in_Germany
# /wiki/Expulsion_of_Muslims_from_the_Northern_province_by_LTTE
# /wiki/Indo-Sri_Lanka_Accord
# /wiki/Pan-African_e-Network_project
# /wiki/India%E2%80%93Portugal_relations
# /wiki/India%E2%80%93Zimbabwe_relations
# /wiki/Indira_Gandhi
# /wiki/Morarji_Desai
# /wiki/Seven_Social_Sins
# /wiki/Tushar_Gandhi
# /wiki/Swami_Anand
# /wiki/Brajkishore_Prasad
# /wiki/Ekla_Chalo_Re
# /wiki/Rabindra_Nritya_Natya
# /wiki/Bhadu_(festival)
# /wiki/Oladevi
# /wiki/Chalchitra
# /wiki/Tant_sari
# /wiki/Theatre_in_Bangladesh
# /wiki/Bengali_poetry
# /wiki/Farrukh_Ahmad
# /wiki/Islamic_Renaissance
# /wiki/Guardianship_of_the_Islamic_Jurist
# /wiki/Nematollah_Salehi_Najafabadi
# /wiki/Ulama
# /wiki/Seljuk_Empire
# /wiki/Seljuk_dynasty#Seljuk_rulers_in_Syria
# /wiki/E%C3%B3ganacht_Glendamnach
# /wiki/Cath_Maige_Mucrama
# /wiki/Corcu_Lo%C3%ADgde
# /wiki/Clann_Conla
# /wiki/Sigurd_Hlodvirsson,_Earl_of_Orkney
# /wiki/Orkneyinga_Saga
# /wiki/ISBN_(identifier)
# /wiki/ISO_8601
# /wiki/Combined_Communications_Electronics_Board
# /wiki/US_Military_Communications-Electronics_Board
# /wiki/United_States_Army_Communications-Electronics_Command
# /wiki/Warrant_Officer_Basic_Course
# /wiki/Warrant_Officer_Candidate_School_(United_States_Army)
# /wiki/Continental_Army
# /wiki/Thirteen_Colonies
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Text_Code
# /wiki/ISO/IEC_7816
# /wiki/IS-IS
# /wiki/ISO_10303-28
# /wiki/ISO_657
# /wiki/ISO_7002
# /wiki/ISO_9564
# /wiki/ISO_31-13
# /wiki/ISO/IEC_17024
# /wiki/ISO_10161
# /wiki/ISO_8583
# /wiki/ISO_11784_and_ISO_11785
# /wiki/Shoe_size
# /wiki/ISO/IEC_18014
# /wiki/Simple_feature_access
# /wiki/ISO_19115
# /wiki/GeoMedia
# /wiki/Intergraph_Corporation
# /wiki/IBM
# /wiki/Ulrich_Steinhilper
# /wiki/World_War_II
# /wiki/Belgrade_Offensive
# /wiki/Battle_of_Knin
# /wiki/Second_Balkan_War
# /wiki/First_World_War
# /wiki/Hundred_Days_Offensive#Advance_to_the_Hindenburg_Line
# /wiki/Latvian_War_of_Independence
# /wiki/Lithuanian_Wars_of_Independence
# /wiki/Coat_of_arms_of_Lithuania
# /wiki/Politics_of_Lithuania
# /wiki/1926_Lithuanian_coup_d%27%C3%A9tat
# /wiki/Christianization_of_Lithuania
# /wiki/German_language
# /wiki/Nelly_Sachs
# /wiki/Kenzabur%C5%8D_%C5%8Ce
# /wiki/National_Institute_of_Informatics
# /wiki/MA_(identifier)
# /wiki/RID_(identifier)
# /wiki/VcBA_(identifier)
# /wiki/Maximilian_I,_Duke_of_Bavaria
# /wiki/Elector_of_Bavaria
# /wiki/House_of_Wittelsbach
# /wiki/Alter_Hof
# /wiki/Ludwigstrasse
# /wiki/Museum_Brandhorst
# /wiki/Hellabrunn_Zoo
# /wiki/World_Association_of_Zoos_and_Aquariums
# /wiki/Research
# /wiki/Art_methodology
# /wiki/Narrative
# /wiki/Restitution
# /wiki/Common_law
# /wiki/Abington_School_District_v._Schempp
# /wiki/McCullen_v._Coakley
# /wiki/McGowan_v._Maryland
# /wiki/Patterson_v._Colorado
# /wiki/Hustler_Magazine_v._Falwell
# /wiki/Ward_v._Rock_Against_Racism
# /wiki/U.S._LEXIS
# /wiki/PAX_(event)
# /wiki/Victoria_(Australia)
# /wiki/Geology_of_Australia
# /wiki/Dance_in_Australia
# /wiki/Australian_Ballet_Company
# /wiki/Ballets_Russes
# /wiki/Serge_Lifar
# /wiki/Nijinsky
# /wiki/Le_Spectre_de_la_Rose
# /wiki/Hector_Berlioz
# /wiki/Raden_Saleh
# /wiki/Eug%C3%A8ne_Delacroix
# /wiki/NLA_(identifier)
# /wiki/Billy_Hughes
# /wiki/Shadow_Ministry_of_Kim_Beazley_(2005%E2%80%9306)
# /wiki/Kevin_Rudd
# /wiki/The_Age
# /wiki/Southern_Cross_railway_station
# /wiki/Mernda_railway_line
# /wiki/Orbost_railway_line
# /wiki/Pakenham_railway_station,_Melbourne
# /wiki/Flinders_Street_railway_station
# /wiki/Melbourne_Central_railway_station
# /wiki/Belgrave_railway_station
# /wiki/Geographic_coordinate_system
# /wiki/Bordeaux
# /wiki/Var_(department)
# /wiki/World_War_I
# /wiki/Interwar_period
# /wiki/Canadian_property_bubble
# /wiki/Black_Hills_Gold_Rush
# /wiki/William_Clark
# /wiki/John_Jacob_Astor
# /wiki/Davy_Crockett
# /wiki/Carroll_County,_Tennessee
# /wiki/Henderson_County,_Tennessee
# /wiki/Scotts_Hill,_Tennessee
# /wiki/Cedar_Grove,_Henderson_County,_Tennessee
# /wiki/Census-designated_place
# /wiki/Unincorporated_area
# /wiki/Landscape_park_(protected_area)
# /wiki/National_Park
# /wiki/Wayback_Machine
# /wiki/Robots.txt
# /wiki/Distributed_web_crawling
# /wiki/Google
# /wiki/Queenstown,_Singapore
# /wiki/Johor
# /wiki/Lowland
# /wiki/Manaus
# /wiki/Asian_Brazilian
# /wiki/Japanese_community_of_S%C3%A3o_Paulo
# /wiki/Kyoto_University
# /wiki/ISBN_(identifier)
# /wiki/ISO_704
# /wiki/Film_speed
# /wiki/POSIX
# /wiki/ISO/IEC_6523
# /wiki/List_of_International_Organization_for_Standardization_standards
# /wiki/ISO_843
# /wiki/ISO_31-1
# /wiki/Orders_of_magnitude_(time)
# /wiki/Silicon-germanium#SiGe_transistors
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_8859-16
# /wiki/Code_page_852
# /wiki/Symbol_(typeface)#Encoding
# /wiki/Gautami_(typeface)
# /wiki/Century_Gothic
# /wiki/Spectrum_(typeface)
# /wiki/Doi_(identifier)
# /wiki/MPEG-4_Part_14
# /wiki/135_film
# /wiki/Canon_EOS-1v
# /wiki/Canon_EOS_620
# /wiki/Autofocus
# /wiki/Sony_DSLR-A700
# /wiki/Digital_single-lens_reflex_camera
# /wiki/Canon_EOS_1200D
# /wiki/Canon_EOS_60D
# /wiki/Olympus_PEN_E-PL3
# /wiki/Canon_EOS_650D
# /wiki/Fujifilm
# /wiki/Osaka_Gas
# /wiki/Nidec
# /wiki/Takata_Corporation
# /wiki/General_Motors
# /wiki/General_Motors_South_Africa
# /wiki/GM_Small_Gasoline_Engine
# /wiki/Opel_Corsa
# /wiki/Manual_transmission
# /wiki/Differential_(mechanical_device)
# /wiki/Axle
# /wiki/Bissel_truck
# /wiki/Locomotive
# /wiki/Remote_control_locomotive
# /wiki/Union_Pacific_Railroad
# /wiki/Illinois_and_Midland_Railroad
# /wiki/Midland_Valley_Railroad
# /wiki/Chicago_and_Eastern_Illinois_Railroad
# /wiki/Atlanta,_Birmingham_and_Atlantic_Railway
# /wiki/Ferromex
# /wiki/Florida_East_Coast_Railway
# /wiki/Apoxsee,_Florida
# /wiki/Kenansville,_Florida
# /wiki/Osceola_County,_Florida
# /wiki/1964_United_States_presidential_election
# /wiki/1972_United_States_presidential_election
# /wiki/Spiro_Agnew
# /wiki/James_Eli_Watson
# /wiki/Harry_C._Canfield
# /wiki/Roger_H._Zion
# /wiki/British_Parliament
# /wiki/Council_of_Oman
# /wiki/Council_of_State_of_Oman
# /wiki/Gregorian_calendar
# /wiki/Computus
# /wiki/Feast_of_the_Transfiguration
# /wiki/Good_Friday
# /wiki/ISBN_(identifier)
# /wiki/ISO_3166-3
# /wiki/Portuguese_Timor
# /wiki/Graciosa_fortress
# /wiki/Azemmour
# /wiki/M%C3%A9diouna_Province
# /wiki/Khouribga_Province
# /wiki/T%C3%A9touan_Province
# /wiki/Oujda-Angad_Prefecture
# /wiki/Nador_Province
# /wiki/Sidi_Ifni_Province
# /wiki/Sidi_Ifni
# /wiki/Al_Jazeera
# /wiki/Index_on_Censorship
# /wiki/Daily_Mirror
# /wiki/15_February_2003_anti-war_protest
# /wiki/Victoria,_British_Columbia
# /wiki/National_Historic_Sites_of_Canada
# /wiki/Outline_of_Canada
# /wiki/Religion_in_Canada
# /wiki/Tablets_of_the_Divine_Plan
# /wiki/The_Four_Valleys
# /wiki/Will_and_Testament_of_%CA%BBAbdu%27l-Bah%C3%A1
# /wiki/The_Secret_of_Divine_Civilization
# /wiki/Gleanings_from_the_Writings_of_Bah%C3%A1%CA%BCu%27ll%C3%A1h
# /wiki/Paris_Talks
# /wiki/Bah%C3%A1%CA%BC%C3%AD_Faith
# /wiki/Prophet
# /wiki/Huldah
# /wiki/Noah
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_10116
# /wiki/C%2B%2B
# /wiki/ISBN_(identifier)
# /wiki/Amazon_Kindle
# /wiki/Lektz
# /wiki/Operating_system
# /wiki/Electronic_voting
# /wiki/Spoiled_ballot
# /wiki/Single_transferable_vote
# /wiki/Deakin_University
# /wiki/Burwood_State_College
# /wiki/University_of_Notre_Dame_Australia
# /wiki/Australian_National_University
# /wiki/Flinders_University
# /wiki/Wayback_Machine
# /wiki/Copyright
# /wiki/Music
# /wiki/Republic_(Plato)
# /wiki/Eric_Heinze
# /wiki/Fulbright_Program
# /wiki/Franco-American_Fulbright_Commission
# /wiki/Fulbright-Hays_Act_of_1961
# /wiki/Title_22_of_the_United_States_Code
# /wiki/Title_15_of_the_United_States_Code
# /wiki/Title_39_of_the_United_States_Code
# /wiki/Title_14_of_the_United_States_Code
# /wiki/Title_39_of_the_United_States_Code
# /wiki/United_States_Code
# /wiki/Reconciliation_(United_States_Congress)
# /wiki/Russell_Senate_Office_Building
# /wiki/Committee_of_the_Whole_(United_States_House_of_Representatives)
# /wiki/Mace_of_the_United_States_House_of_Representatives
# /wiki/Article_One_of_the_United_States_Constitution
# /wiki/Articles_of_Confederation
# /wiki/Political_parties_in_the_United_States
# /wiki/Working_Class_Party
# /wiki/Democratic_Party_(United_States)
# /wiki/Plurality_(voting)
# /wiki/Supermajority#Majority_of_the_entire_membership
# /wiki/Objection_to_the_consideration_of_a_question
# /wiki/Disciplinary_procedures
# /wiki/ABC_of_Chairmanship
# /wiki/Walter_Citrine,_1st_Baron_Citrine
# /wiki/Mannerheim_line
# /wiki/Raseborg_Castle
# /wiki/Svartholm_fortress
# /wiki/Ruotsinsalmi_sea_fortress
# /wiki/Korela_Fortress
# /wiki/Decembrist_Revolt
# /wiki/Nationalities_Papers
# /wiki/Turkey
# /wiki/Economy_of_Benin
# /wiki/Benin_at_the_Olympics
# /wiki/Madagascar_at_the_Olympics
# /wiki/Russia
# /wiki/Saint_Petersburg
# /wiki/Mikhail_Boyarsky
# /wiki/Typecast
# /wiki/Sergio_Leone
# /wiki/NKC_(identifier)
# /wiki/Charles_University_in_Prague
# /wiki/Zl%C3%ADn
# /wiki/%C5%A0koda_24Tr_Irisbus
# /wiki/Irisbus_Citelis
# /wiki/JGSP_Novi_Sad
# /wiki/Equity_(finance)
# /wiki/Positive_accounting
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Recording_Code
# /wiki/ISO_8601
# /wiki/ISO_2852
# /wiki/ISO_657
# /wiki/ISO_704
# /wiki/ISO/IEC_7811
# /wiki/ISO_15924
# /wiki/Tengwar
# /wiki/L%C3%A1adan
# /wiki/Bolak_language
# /wiki/Ido_(language)
# /wiki/Don_Harlow
# /wiki/Interlingue
# /wiki/OCLC_(identifier)
# /wiki/Information_Today
# /wiki/Speech_Technology_(magazine)
# /wiki/Information_Today,_Inc.
# /wiki/ISSN_(identifier)
# /wiki/Shoe_size
# /wiki/ISO/IEC_27000
# /wiki/ISO_7010
# /wiki/ISO/IEC_7810
# /wiki/ISO_639-6
# /wiki/ISO_639-5
# /wiki/ISO_31-13
# /wiki/ISO_3166-3
# /wiki/East_Timor
# /wiki/East_Timor_(Indonesian_province)
# /wiki/Sundanese_language
# /wiki/Maguindanao_language
# /wiki/Obo_language
# /wiki/Ratagnon_language
# /wiki/Central_Cordilleran_languages
# /wiki/Kankanaey_language
# /wiki/Itneg_language
# /wiki/Malaysian_language
# /wiki/Languages_of_Japan
# /wiki/Ryukyuan_languages
# /wiki/Austronesian_languages
# /wiki/Philistine_language
# /wiki/Wanderwort
# /wiki/Arabic
# /wiki/Ammonite_language
# /wiki/French_National_Centre_for_Scientific_Research
# /wiki/BNF_(identifier)
# /wiki/Mus%C3%A9e_de_l%27Air
# /wiki/Geographic_coordinate_system
# /wiki/115th_meridian_east
# /wiki/60th_parallel_south
# /wiki/180th_meridian
# /wiki/75th_meridian_west
# /wiki/Ica_Region
# /wiki/Peru
# /wiki/ISBN_(identifier)
# /wiki/Check_bit
# /wiki/OCLC_(identifier)
# /wiki/NetLibrary
# /wiki/Digital_restrictions_management#DRM_and_e-books
# /wiki/Denial-of-service_attack
# /wiki/BlackNurse_(Computer_Security)
# /wiki/CryptoLocker
# /wiki/Sophos
# /wiki/Cisco_Systems
# /wiki/Element_Anti-Virus
# /wiki/Software_release_life_cycle#BETA
# /wiki/Retail_software
# /wiki/Sneakernet
# /wiki/Soulseek
# /wiki/Magnet_URI_scheme
# /wiki/Base32
# /wiki/Base64
# /wiki/CSS
# /wiki/IBM_Home_Page_Reader
# /wiki/Internet_Explorer
# /wiki/Session_Manager_Subsystem
# /wiki/Windows_To_Go
# /wiki/List_of_games_included_with_Windows
# /wiki/ActiveMovie
# /wiki/Spyglass,_Inc.
# /wiki/HTML_Components
# /wiki/Internet_Explorer_Mobile
# /wiki/Bing_Audio
# /wiki/Software_categories#Categorization_approaches
# /wiki/Hunting
# /wiki/Doi_(identifier)
# /wiki/JBIG
# /wiki/IATF_16949
# /wiki/ISO_19600
# /wiki/ISO_17100
# /wiki/CHILL
# /wiki/ISO_15706-2
# /wiki/International_Standard_Text_Code
# /wiki/Legal_Entity_Identifier
# /wiki/Kunrei-shiki_romanization
# /wiki/Japanese_numerals
# /wiki/Myriad
# /wiki/First_French_Republic
# /wiki/Fran%C3%A7ois_Christophe_de_Kellermann
# /wiki/Dechristianization_of_France_during_the_French_Revolution#The_Revolution_and_the_Church
# /wiki/Emmanuel_Joseph_Siey%C3%A8s
# /wiki/Kingdom_of_Prussia
# /wiki/Lutheran
# /wiki/Sacramental_union
# /wiki/Homily
# /wiki/Lector
# /wiki/Pax_(liturgy)
# /wiki/Pro_multis
# /wiki/Oremus
# /wiki/Code_of_Rubrics
# /wiki/Sacrosanctum_Concilium
# /wiki/Personal_ordinariate
# /wiki/Holy_day_of_obligation
# /wiki/Jus_patronatus
# /wiki/Auditor_(ecclesiastical)
# /wiki/Manifestation_of_Conscience
# /wiki/Appointment_of_Catholic_bishops
# /wiki/Person_(Catholic_canon_law)
# /wiki/Pietro_Gasparri
# /wiki/Order_of_the_Tower_and_Sword
# /wiki/Military_order_(society)
# /wiki/Zaire_Use
# /wiki/Anti-Catholicism
# /wiki/History_of_Christian_thought_on_persecution_and_tolerance
# /wiki/Swiss_Brethren
# /wiki/Schaffhausen
# /wiki/Petrozavodsk
# /wiki/Neubrandenburg
# /wiki/Tollensesee
# /wiki/Pomeranian_Voivodeship
# /wiki/National_Park
# /wiki/Viru_Bog
# /wiki/Harju_County
# /wiki/Maardu
# /wiki/Harju_County
# /wiki/Saue
# /wiki/Rakvere
# /wiki/Georgia_(country)
# /wiki/China
# /wiki/Culture_hero
# /wiki/Odin
# /wiki/T%C3%BDr
# /wiki/Logi
# /wiki/Gylfi
# /wiki/Hervarar_saga
# /wiki/N%C4%AB%C3%BE
# /wiki/Alvaldi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-37b874eb048c> in <module>
#       2     newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
#       3     print(newArticle)
# ----> 4     links = getLinks(newArticle)
#
# <ipython-input-7-91c7fcaab027> in getLinks(articleUrl)
#       1 def getLinks(articleUrl):
# ----> 2     html = urlopen("http://en.wikipedia.org"+articleUrl)
#       3     bsObj = BeautifulSoup(html)
#       4     return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))
#
# ~\devResources\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\devResources\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\devResources\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\devResources\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\devResources\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\devResources\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\devResources\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~\devResources\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~\devResources\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\devResources\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\devResources\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\devResources\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\devResources\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\devResources\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Rastreando um site inteiro

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()

def getLinks(pageUrl):
    
    global pages
    
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html)
    
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        
        if 'href' in link.attrs:
            
            if link.attrs['href'] not in pages:
                
                # Encontramos uma página nova
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/File:A_coloured_voting_box.svg
# /wiki/Wikipedia:Protection_policy#full
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1166dc18ba2c> in <module>
#      23                 pages.add(newPage)
#      24                 getLinks(newPage)
# ---> 25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      22                 print(newPage)
#      23                 pages.add(newPage)
# ---> 24                 getLinks(newPage)
#      25 getLinks("")
#
# <ipython-input-10-1166dc18ba2c> in getLinks(pageUrl)
#      10
#      11     html = urlopen("http://en.wikipedia.org"+pageUrl)
# ---> 12     bsObj = BeautifulSoup(html)
#      13
#      14     for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
#
# ~\devResources\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     307
#     308         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 309             markup = markup.read()
#     310         elif len(markup) <= 256 and (
#     311                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~\devResources\anaconda3\lib\http\client.py in read(self, amt)
#     469             else:
#     470                 try:
# --> 471                     s = self._safe_read(self.length)
#     472                 except IncompleteRead:
#     473                     self._close_conn()
#
# ~\devResources\anaconda3\lib\http\client.py in _safe_read(self, amt)
#     610         IncompleteRead exception can be used to detect the problem.
#     611         """
# --> 612         data = self.fp.read(amt)
#     613         if len(data) < amt:
#     614             raise IncompleteRead(data, amt-len(data))
#
# ~\devResources\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\devResources\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\devResources\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Coletando dados em um site inteiro

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()

def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html)
    
    try:
        print(bsObj.h1.get_text())
        print(bsObj.find(id = "mw-content-text").findAll("p")[0])
        print(bsObj.find(id = "ca-edit").find("span").find("a").attrs['href'])
    
    except AttributeError:
        
        print("This page is missing somenthing! No worries though!")
    
        
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        
        if 'href' in link.attrs:
            
            if link.attrs['href'] not in pages:
                
                # Encontramos uma página nova
                newPage = link.attrs['href']
                print("--------------\n" + newPage)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")

# %% [markdown]
# # Rastreando na Internet

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

# %%
#Recupera uma lista de todos os links internos encontrados em uma página
def getInternalLinks(bsObj, includeUrl):
    
    internalLinks = []
    
    # Encontra todos os links que começa com a "/"
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
    
    return internalLinks

# %%
# Recupera uma lista de todos os links externos encontrados em uma página
def getExernalLinks(bsObj, excludeUrl):
        
    externalLinks = []
    
    # Encontra todos os links que começa com a "http" ou "www" que não contêm url atual
    for link in bsObj.findAll("a", href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    
    return externalLinks

# %%
def splitAddress(address):
    
    addressParts = address.replace("http://", "").split("/")
    return addressParts

# %%
def getRandomExternalLink(startingPage):
    
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html)
    
    externalLinks = getExernalLinks(bsObj, splitAddress(startingPage)[0])
    
    if len(externalLinks) == 0:
        internalLinks = getInternalLinks(startingPage)
        return getNextExternalLink(internalLinks[random.randint(0, len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]

# %%
def followExternalOnly(startingSite):
    
    externalLink = getRandomExternalLink("http://oreilly.com")
    print("Random external link is:" + externalLink)
    followExternalOnly(externalLink)

# %%
followExternalOnly("http://oreilly.com")
# Out:
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://www.youtube.com/user/OreillyMedia
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# Random external link is:https://www.linkedin.com/company/oreilly-media
# Random external link is:https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is:https://www.facebook.com/OReilly/
# Random external link is:https://twitter.com/oreillymedia
# Random external link is:https://play.google.com/store/apps/details?id=com.safariflow.queue
# Random external link is:https://www.youtube.com/user/OreillyMedia
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\devResources\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\devResources\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\devResources\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~\devResources\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~\devResources\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~\devResources\anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~\devResources\anaconda3\lib\http\client.py in connect(self)
#    1416
# -> 1417             super().connect()
#    1418
#
# ~\devResources\anaconda3\lib\http\client.py in connect(self)
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#
# ~\devResources\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\devResources\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-19-908aa98f31e2> in <module>
# ----> 1 followExternalOnly("http://oreilly.com")
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
# ...
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
# ----> 5     followExternalOnly(externalLink)
#
# <ipython-input-18-9e9c8dbb4653> in followExternalOnly(startingSite)
#       1 def followExternalOnly(startingSite):
#       2
# ----> 3     externalLink = getRandomExternalLink("http://oreilly.com")
#       4     print("Random external link is:" + externalLink)
#       5     followExternalOnly(externalLink)
#
# <ipython-input-15-e6fd7e261173> in getRandomExternalLink(startingPage)
#       1 def getRandomExternalLink(startingPage):
#       2
# ----> 3     html = urlopen(startingPage)
#       4     bsObj = BeautifulSoup(html)
#       5
#
# ~\devResources\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\devResources\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\devResources\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\devResources\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\devResources\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\devResources\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\devResources\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\devResources\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\devResources\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\devResources\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\devResources\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~\devResources\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#    1355         except:
#
# URLError: <urlopen error [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu>

# %%
# Coleta uma lista de todos os URLS

allExtLinks = set()
allIntLinks = set()

def getAllExternalLinks(siteUrl):
    
    html = urlopen(siteUrl)
    bsObj = BeautifulSoup(html)
    
    internalLinks = getInternalLinks(bsObj, splitAddress(siteUrl)[0])
    externalLinks = getExernalLinks(bsObj, splitAddress(siteUrl)[0])
    
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    
    for link in internalLinks:
        if link not in allIntLinks:
            print("About to get link: {}".format(link))
            allIntLinks.add(link)
            getAllExternalLinks(link)
            
getAllExternalLinks("http://www.mrafaelbatista.dev")
# Out:
# https://mrafaelbatista.dev/site/
# https://mrafaelbatista.dev/site/index.php/pagina-principal/
# https://mrafaelbatista.dev/site/#about-me
# https://mrafaelbatista.dev/site/#my-social-medias
# https://www.youtube.com/c/messiasbatista
# https://medium.com/@mrafaelbatista
# https://mrafaelbatista.dev/site/instagram.com/gdgjoaopessoa
# https://www.instagram.com/mrafaelbatista.dev
# https://twitter.com/mrafaelbatista
# https://www.linkedin.com/in/messiasbatista
# https://github.com/mrafaelbatista
# https://extendthemes.com/go/built-with-highlight/

# %% [markdown]
# # Rastreando com o Scrapy
#
# Será trabalhando em um diretório com o VSCode.
